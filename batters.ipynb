# %%
import pandas
from sklearn import preprocessing

# %%
batters = pandas.read_csv("data/FantasyPros_2019_Projections_H.csv")

# %%
stats = ["R", "HR", "RBI", "SB", "OBP"]
normalised_stats = ["{}norm".format(col) for col in stats]

# %%
# Normalise
x = batters[stats].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(batters[stats])
normalised = pandas.DataFrame(x_scaled, columns=batters[stats].columns)
batters = batters.join(normalised, rsuffix="norm")

# %%
batters["score"] = batters[normalised_stats].mean(axis=1)

# %%
filtered = batters
filtered[["Player", "Own", "Team", "Positions", "score"] + stats + normalised_stats].sort_values("score", ascending=False)
# Out:
#                     Player  Own Team    Positions     score      R    HR  \
# 0               Mike Trout  99%  LAA        CF,DH  0.843202  113.0  39.0
# 1             Mookie Betts  99%  BOS        CF,RF  0.765981  117.0  30.0
# 2             Jose Ramirez  99%  CLE        2B,3B  0.722650  101.0  30.0
# 4            J.D. Martinez  99%  BOS     LF,RF,DH  0.710741   98.0  40.0
# 9             Bryce Harper  99%  PHI        CF,RF  0.705820   99.0  34.0
# 13             Aaron Judge  99%  NYY        RF,DH  0.679226   99.0  38.0
# 5         Christian Yelich  99%  MIL     LF,CF,RF  0.677884  102.0  28.0
# 16       Giancarlo Stanton  99%  NYY     LF,RF,DH  0.675840   97.0  43.0
# 3            Nolan Arenado  99%  COL           3B  0.670350   99.0  37.0
# 6              Trea Turner  99%  WSH           SS  0.668248   96.0  18.0
# 7             Ronald Acuna  99%  ATL        LF,CF  0.658890   96.0  30.0
# 17        Paul Goldschmidt  99%  STL           1B  0.657842   96.0  30.0
# 8         Francisco Lindor  99%  CLE           SS  0.650641  101.0  29.0
# 14            Trevor Story  99%  COL           SS  0.648126   85.0  33.0
# 23               Juan Soto  99%  WSH           LF  0.639811   94.0  29.0
# 11            Alex Bregman  99%  HOU        3B,SS  0.639789   98.0  28.0
# 27            Rhys Hoskins  99%  PHI        1B,LF  0.634325   92.0  36.0
# 26             Khris Davis  99%  OAK        LF,DH  0.626171   90.0  42.0
# 15         Freddie Freeman  99%  ATL           1B  0.620985   92.0  27.0
# 12           Manny Machado  99%   SD        3B,SS  0.619955   86.0  33.0
# 22           Anthony Rizzo  99%  CHC           1B  0.614250   88.0  29.0
# 19        Charlie Blackmon  99%  COL           CF  0.612220  106.0  28.0
# 10             Jose Altuve  99%  HOU           2B  0.611219   95.0  18.0
# 30          Cody Bellinger  99%  LAD        1B,CF  0.608368   87.0  31.0
# 18             Javier Baez  99%  CHC     2B,3B,SS  0.607765   87.0  30.0
# 20       Andrew Benintendi  99%  BOS        LF,CF  0.606178   98.0  18.0
# 61              Joey Gallo  86%  TEX  1B,LF,CF,RF  0.598086   85.0  40.0
# 21             Kris Bryant  99%  CHC        3B,RF  0.592988   96.0  28.0
# 42             Nelson Cruz  92%  MIN           DH  0.584361   81.0  35.0
# 34       Adalberto Mondesi  95%   KC        2B,SS  0.578526   75.0  20.0
# ..                     ...  ...  ...          ...       ...    ...   ...
# 478             Eric Haase   0%  CLE            C  0.081141   11.0   4.0
# 462        Jacob Stallings   0%  PIT            C  0.081055    9.0   1.0
# 476        Jhonatan Solano   0%  NaN            C  0.080470   14.0   2.0
# 314       Christian Arroyo   0%   TB        2B,3B  0.078680    9.0   2.0
# 502            Beau Taylor   0%  OAK            C  0.077641    9.0   1.0
# 467        Kyle Higashioka   0%  NYY            C  0.076726   10.0   3.0
# 649       Cliff Pennington   0%  NaN           3B  0.075109   14.0   1.0
# 480       Jacob Nottingham   0%  MIL            C  0.072795   10.0   3.0
# 471           Jose Trevino   0%  TEX            C  0.071619   13.0   2.0
# 495         Pedro Severino   0%  WSH            C  0.070305   10.0   2.0
# 466          Bryan Holaday   0%  MIA            C  0.069215    9.0   2.0
# 710         Shane Robinson   0%  PHI           RF  0.068963   13.0   0.0
# 461           Bobby Wilson   0%  DET            C  0.067959   11.0   3.0
# 483           Jose Lobaton   0%  SEA            C  0.065885    5.0   1.0
# 715              Matt Winn   0%   SF            C  0.065064   17.0   4.0
# 617         Gregorio Petit   0%  PHI        2B,SS  0.064300   10.0   1.0
# 459         Francisco Pena   0%  STL            C  0.063530   10.0   2.0
# 716  Jarrod Saltalamacchia   0%  NaN         C,1B  0.061808   12.0   4.0
# 472             Tomas Nido   0%  NYM            C  0.061538   11.0   2.0
# 713            Javy Guerra   0%   SD           SS  0.059639   13.0   3.0
# 717            Gift Ngoepe   0%  PHI        2B,SS  0.056785   11.0   2.0
# 510          Juan Graterol   0%  CIN            C  0.056317   11.0   1.0
# 490             Joe Hudson   0%  STL            C  0.054914    8.0   2.0
# 488            Nick Ciuffo   0%   TB            C  0.048242    8.0   1.0
# 650             Pete Kozma   0%  DET        3B,SS  0.046155   14.0   1.0
# 493             Rocky Gale   0%  LAD            C  0.040659    8.0   1.0
# 505             Adam Moore   0%  NaN            C  0.035679    5.0   1.0
# 513          Chris Stewart   0%   SD            C  0.027378    6.0   0.0
# 718                    NaN  NaN  NaN          NaN       NaN    NaN   NaN
# 719                    NaN  NaN  NaN          NaN       NaN    NaN   NaN
#
#        RBI    SB    OBP     Rnorm    HRnorm   RBInorm    SBnorm   OBPnorm
# 0     96.0  24.0  0.440  0.964286  0.906977  0.823009  0.521739  1.000000
# 1     93.0  27.0  0.387  1.000000  0.697674  0.796460  0.586957  0.748815
# 2     96.0  25.0  0.375  0.857143  0.697674  0.823009  0.543478  0.691943
# 4    116.0   4.0  0.378  0.830357  0.930233  1.000000  0.086957  0.706161
# 9     99.0  11.0  0.400  0.839286  0.790698  0.849558  0.239130  0.810427
# 13    94.0   7.0  0.380  0.839286  0.883721  0.805310  0.152174  0.715640
# 5     93.0  17.0  0.378  0.866071  0.651163  0.796460  0.369565  0.706161
# 16   109.0   3.0  0.346  0.821429  1.000000  0.938053  0.065217  0.554502
# 3    113.0   2.0  0.363  0.839286  0.860465  0.973451  0.043478  0.635071
# 6     69.0  46.0  0.340  0.812500  0.418605  0.584071  1.000000  0.526066
# 7     86.0  23.0  0.345  0.812500  0.697674  0.734513  0.500000  0.549763
# 17    94.0  11.0  0.384  0.812500  0.697674  0.805310  0.239130  0.734597
# 8     85.0  19.0  0.352  0.857143  0.674419  0.725664  0.413043  0.582938
# 14    98.0  20.0  0.331  0.714286  0.767442  0.840708  0.434783  0.483412
# 23    94.0   7.0  0.392  0.794643  0.674419  0.805310  0.152174  0.772512
# 11    94.0  11.0  0.371  0.830357  0.651163  0.805310  0.239130  0.672986
# 27   103.0   5.0  0.348  0.776786  0.837209  0.884956  0.108696  0.563981
# 26   110.0   1.0  0.319  0.758929  0.976744  0.946903  0.021739  0.426540
# 15    93.0   8.0  0.383  0.776786  0.627907  0.796460  0.173913  0.729858
# 12    96.0  10.0  0.349  0.723214  0.767442  0.823009  0.217391  0.568720
# 22    99.0   7.0  0.367  0.741071  0.674419  0.849558  0.152174  0.654028
# 19    77.0  12.0  0.354  0.901786  0.651163  0.654867  0.260870  0.592417
# 10    78.0  22.0  0.375  0.803571  0.418605  0.663717  0.478261  0.691943
# 30    92.0  12.0  0.343  0.732143  0.720930  0.787611  0.260870  0.540284
# 18    97.0  17.0  0.315  0.732143  0.697674  0.831858  0.369565  0.407583
# 20    84.0  20.0  0.362  0.830357  0.418605  0.716814  0.434783  0.630332
# 61    93.0   5.0  0.322  0.714286  0.930233  0.796460  0.108696  0.440758
# 21    84.0   6.0  0.367  0.812500  0.651163  0.716814  0.130435  0.654028
# 42   101.0   1.0  0.343  0.678571  0.813953  0.867257  0.021739  0.540284
# 34    67.0  44.0  0.288  0.625000  0.465116  0.566372  0.956522  0.279621
# ..     ...   ...    ...       ...       ...       ...       ...       ...
# 478   13.0   0.0  0.265  0.053571  0.093023  0.088496  0.000000  0.170616
# 462   10.0   0.0  0.289  0.035714  0.023256  0.061947  0.000000  0.284360
# 476   14.0   1.0  0.262  0.080357  0.046512  0.097345  0.021739  0.156398
# 314   10.0   1.0  0.277  0.035714  0.046512  0.061947  0.021739  0.227488
# 502    7.0   0.0  0.291  0.035714  0.023256  0.035398  0.000000  0.293839
# 467   12.0   0.0  0.269  0.044643  0.069767  0.079646  0.000000  0.189573
# 649    9.0   2.0  0.266  0.080357  0.023256  0.053097  0.043478  0.175355
# 480   10.0   1.0  0.264  0.044643  0.069767  0.061947  0.021739  0.165877
# 471   13.0   0.0  0.261  0.071429  0.046512  0.088496  0.000000  0.151659
# 495   11.0   0.0  0.269  0.044643  0.046512  0.070796  0.000000  0.189573
# 466   13.0   0.0  0.266  0.035714  0.046512  0.088496  0.000000  0.175355
# 710    8.0   4.0  0.259  0.071429  0.000000  0.044248  0.086957  0.142180
# 461   13.0   0.0  0.256  0.053571  0.069767  0.088496  0.000000  0.127962
# 483    6.0   0.0  0.288  0.000000  0.023256  0.026549  0.000000  0.279621
# 715   15.0   0.0  0.233  0.107143  0.093023  0.106195  0.000000  0.018957
# 617    8.0   2.0  0.264  0.044643  0.023256  0.044248  0.043478  0.165877
# 459    9.0   1.0  0.261  0.044643  0.046512  0.053097  0.021739  0.151659
# 716   12.0   1.0  0.240  0.062500  0.093023  0.079646  0.021739  0.052133
# 472   12.0   0.0  0.256  0.053571  0.046512  0.079646  0.000000  0.127962
# 713   14.0   1.0  0.237  0.071429  0.069767  0.097345  0.021739  0.037915
# 717    9.0   1.0  0.252  0.053571  0.046512  0.053097  0.021739  0.109005
# 510    9.0   0.0  0.261  0.053571  0.023256  0.053097  0.000000  0.151659
# 490    7.0   0.0  0.264  0.026786  0.046512  0.035398  0.000000  0.165877
# 488    8.0   0.0  0.260  0.026786  0.023256  0.044248  0.000000  0.146919
# 650   10.0   3.0  0.229  0.080357  0.023256  0.061947  0.065217  0.000000
# 493    8.0   0.0  0.252  0.026786  0.023256  0.044248  0.000000  0.109005
# 505    5.0   0.0  0.258  0.000000  0.023256  0.017699  0.000000  0.137441
# 513    3.0   0.0  0.256  0.008929  0.000000  0.000000  0.000000  0.127962
# 718    NaN   NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 719    NaN   NaN    NaN       NaN       NaN       NaN       NaN       NaN
#
# [720 rows x 15 columns]

# %%
# %store batters
# Out:
# Stored 'batters' (DataFrame)
